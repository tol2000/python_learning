# %%
# !pip install pandas
# !pip install pandasql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/tolic/.local/lib/python3.10/site-packages (1.4.1)
# Requirement already satisfied: pytz>=2020.1 in /home/tolic/.local/lib/python3.10/site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/lib/python3.10/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.21.0 in /home/tolic/.local/lib/python3.10/site-packages (from pandas) (1.22.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandasql in /home/tolic/.local/lib/python3.10/site-packages (0.7.3)
# Requirement already satisfied: numpy in /home/tolic/.local/lib/python3.10/site-packages (from pandasql) (1.22.2)
# Requirement already satisfied: pandas in /home/tolic/.local/lib/python3.10/site-packages (from pandasql) (1.4.1)
# Requirement already satisfied: sqlalchemy in /home/tolic/.local/lib/python3.10/site-packages (from pandasql) (1.4.31)
# Requirement already satisfied: pytz>=2020.1 in /home/tolic/.local/lib/python3.10/site-packages (from pandas->pandasql) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/lib/python3.10/site-packages (from pandas->pandasql) (2.8.1)
# Requirement already satisfied: greenlet!=0.4.17 in /home/tolic/.local/lib/python3.10/site-packages (from sqlalchemy->pandasql) (1.1.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->pandasql) (1.16.0)

# %%
import pandas as pd
import pandasql as ps
import json

csv_name = 'cars.csv'

cars = pd.DataFrame(
    {
        'speed': [300, 200, 140],
        'engine': [5, 0, 3],
        'doors': [2, 4, 5],
    }, index=pd.Index(['lambo', 'tesla', 'lr'], name='car')
)

cars
# Out:
#        speed  engine  doors
# car
# lambo    300       5      2
# tesla    200       0      4
# lr       140       3      5

# %%
cars.to_csv(csv_name)

# %%
cars = pd.read_csv(csv_name, index_col='car')
cars_wo_index = pd.read_csv(csv_name)

# %%
cars
cars_wo_index
# Out:
#        speed  engine  doors
# car
# lambo    300       5      2
# tesla    200       0      4
# lr       140       3      5
#      car  speed  engine  doors
# 0  lambo    300       5      2
# 1  tesla    200       0      4
# 2     lr    140       3      5

# %%
ti = pd.read_csv('titanic.csv', index_col=0)
ti
# Out:
#                                                       Name PClass    Age  \
# PassengerID
# 1                             Allen, Miss Elisabeth Walton    1st  29.00
# 2                              Allison, Miss Helen Loraine    1st   2.00
# 3                      Allison, Mr Hudson Joshua Creighton    1st  30.00
# 4            Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00
# 5                            Allison, Master Hudson Trevor    1st   0.92
# ...                                                    ...    ...    ...
# 1309                                    Zakarian, Mr Artun    3rd  27.00
# 1310                                Zakarian, Mr Maprieder    3rd  26.00
# 1311                                      Zenni, Mr Philip    3rd  22.00
# 1312                                      Lievens, Mr Rene    3rd  24.00
# 1313                                        Zimmerman, Leo    3rd  29.00
#
#                 Sex  Survived  SexCode
# PassengerID
# 1            female         1        1
# 2            female         0        1
# 3              male         0        0
# 4            female         0        1
# 5              male         1        0
# ...             ...       ...      ...
# 1309           male         0        0
# 1310           male         0        0
# 1311           male         0        0
# 1312           male         0        0
# 1313           male         0        0
#
# [1313 rows x 6 columns]

# %%
sql = """
select 
       --sex, survived,
       count(Name), count(Age), count(SexCode), count(*)
  from ti
--  group by sex, survived
--  order by sex, survived
"""
sql1 = """
select case when age is null then 'null' else 'not null' end as age_is_null, count(*)
  from ti
  group by case when age is null then 'null' else 'not null' end
"""

# %%
ps.sqldf(sql)
ps.sqldf(sql1)
ps.sqldf("select * from ti where age is null limit 5")
ps.sqldf("select * from ti where age is not null limit 5")
# Out:
#    count(Name)  count(Age)  count(SexCode)  count(*)
# 0         1313         756            1313      1313
#   age_is_null  count(*)
# 0    not null       756
# 1        null       557
#    PassengerID                          Name PClass   Age     Sex  Survived  \
# 0           13  Aubert, Mrs Leontine Pauline    1st  None  female         1
# 1           14      Barkworth, Mr Algernon H    1st  None    male         1
# 2           15            Baumann, Mr John D    1st  None    male         0
# 3           30       Borebank, Mr John James    1st  None    male         0
# 4           33            Bradley, Mr George    1st  None    male         1
#
#    SexCode
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0
#    PassengerID                                           Name PClass    Age  \
# 0            1                   Allen, Miss Elisabeth Walton    1st  29.00
# 1            2                    Allison, Miss Helen Loraine    1st   2.00
# 2            3            Allison, Mr Hudson Joshua Creighton    1st  30.00
# 3            4  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00
# 4            5                  Allison, Master Hudson Trevor    1st   0.92
#
#       Sex  Survived  SexCode
# 0  female         1        1
# 1  female         0        1
# 2    male         0        0
# 3  female         0        1
# 4    male         1        0

# %%
ps.sqldf("select * from ti where PClass='*'")
# Out:
#    PassengerID                 Name PClass   Age   Sex  Survived  SexCode
# 0          457  Jacobsohn Mr Samuel      *  None  male         0        0

# %%
ti.loc[ti.PClass=='*']
# Out:
#                             Name PClass  Age   Sex  Survived  SexCode
# PassengerID
# 457          Jacobsohn Mr Samuel      *  NaN  male         0        0

# %%
ti.PClass=='*'
# Out:
# PassengerID
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 1309    False
# 1310    False
# 1311    False
# 1312    False
# 1313    False
# Name: PClass, Length: 1313, dtype: bool

# %%
sql_surv_class = """
select 
       PClass, survived, count(*)
  from ti
  group by PClass, survived
  order by 1, 2
"""

# %%
ps.sqldf(sql_surv_class)
# Out:
#   PClass  Survived  count(*)
# 0      *         0         1
# 1    1st         0       129
# 2    1st         1       193
# 3    2nd         0       160
# 4    2nd         1       119
# 5    3rd         0       573
# 6    3rd         1       138

# %%
ti.pivot_table(
    index=['Sex'],
    columns=['PClass'],
    values='Age',
    aggfunc='median',
)
# Out:
# PClass   1st   2nd   3rd
# Sex
# female  38.0  28.0  22.0
# male    42.0  28.0  25.5

# %%
ti.pivot_table(
    index=['Survived'],
    columns=['PClass'],
    values='Age',
    aggfunc='median',
)
# Out:
# PClass     1st   2nd   3rd
# Survived
# 0         46.0  29.5  25.0
# 1         36.0  25.0  22.0

# %%
data = pd.read_csv('weights.csv', index_col=0)
data.index.name = 'date'
data
# Out:
#             AT0000A18XM4 SW  BE0974268972 BB  US0527691069 US  \
# date
# 2014-01-14         0.184660         0.275706         0.303425
# 2014-01-15         0.225875         0.147861         0.151211
# 2014-01-16         0.261017         0.334213         0.293336
# 2014-01-17         0.160168         0.231034         0.092674
# 2014-01-18         0.057162         0.254146         0.027286
# ...                     ...              ...              ...
# 2018-02-28         0.123821         0.167899         0.120844
# 2018-03-01         0.035043         0.289624         0.220871
# 2018-03-02         0.397155         0.362025         0.050554
# 2018-03-03         0.319902         0.277405         0.051719
# 2018-03-06         0.057699         0.352290         0.291162
#
#             DE0007164600 GR  US6092071058 US
# date
# 2014-01-14         0.042841         0.193368
# 2014-01-15         0.224074         0.250978
# 2014-01-16         0.015744         0.095690
# 2014-01-17         0.269050         0.247074
# 2014-01-18         0.480660         0.180746
# ...                     ...              ...
# 2018-02-28         0.088780         0.498657
# 2018-03-01         0.136366         0.318096
# 2018-03-02         0.020247         0.170019
# 2018-03-03         0.008164         0.342810
# 2018-03-06         0.197700         0.101148
#
# [1081 rows x 5 columns]

# %%
sql_data = """
select case
         when sum_of_columns = 1 then '==1'
         when sum_of_columns < 1 then '<1'
         when sum_of_columns > 1 then '>1'
         else '?'
       end as sum_rel_to_1,
       sum_of_columns, count(*) as qnty, min(date) as min_date, max(date) as max_date
  from (
    select date, "AT0000A18XM4 SW" + "BE0974268972 BB" + "US0527691069 US" + "DE0007164600 GR" + "US6092071058 US" as sum_of_columns
      from data
      --where sum_of_columns=1
  ) a
  group by sum_of_columns
  order by qnty desc
"""

# pd.set_option("display.precision", 40)
data_cols_sum = ps.sqldf(sql_data)
data_cols_sum.to_csv('weights_cols_summary.csv')
with pd.option_context('display.precision', 20, 'display.max_rows', 10):
    data_cols_sum
# Out:
#     sum_rel_to_1          sum_of_columns  qnty    min_date    max_date
# 0            ==1  1.00000000000000000000   165  2014-01-15  2018-02-13
# 1             >1  1.00000000000009992007    46  2014-01-14  2018-01-04
# 2             >1  1.00000000000029998226    45  2014-01-21  2018-02-02
# 3             <1  0.99999999999979993781    44  2014-03-15  2018-01-02
# 4             >1  1.00000000000020006219    37  2014-02-19  2018-01-27
# ..           ...                     ...   ...         ...         ...
# 145           <1  0.99999999999900024417     1  2016-04-12  2016-04-12
# 146           <1  0.99999999999894995106     1  2017-11-23  2017-11-23
# 147           <1  0.99999999999892008606     1  2015-12-31  2015-12-31
# 148           <1  0.99999999999869992884     1  2017-02-23  2017-02-23
# 149           <1  0.99999999999860000877     1  2017-12-15  2017-12-15
#
# [150 rows x 5 columns]

# %%
import numpy as np


def quantile_high(x):
    return x.quantile(.99, interpolation='nearest')


def quantile_low(x):
    return x.quantile(.01, interpolation='nearest')


def quantile_50(x):
    return x.quantile(.5, interpolation='nearest')


def second(x):
    return sorted(x.array)[1]


def before_last(x):
    return sorted(x.array)[-2]


with pd.option_context('display.precision', 20, 'display.max_rows', 20):
    data.agg([np.min, second, quantile_low, np.max, before_last, quantile_high, np.sum, np.median, quantile_50])
# Out:
#                         AT0000A18XM4 SW           BE0974268972 BB  \
# amin             0.00006324065623360000    0.00001772070035710000
# second           0.00056832608789499995    0.00005853430333830000
# quantile_low     0.00350278153427000015    0.00493473843680999977
# amax             0.58878311877500000282    0.63858269868700001659
# before_last      0.51422848409499999356    0.63294675020099999685
# quantile_high    0.45644152804600002238    0.50502054067799995174
# sum            207.61007571537618332513  219.56080655585805061492
# median           0.18887609421900000695    0.20149625733699999541
# quantile_50      0.18887609421900000695    0.20149625733699999541
#
#                         US0527691069 US           DE0007164600 GR  \
# amin             0.00033072555740600002    0.00000028957406732000
# second           0.00060501499727000005    0.00089959071450700003
# quantile_low     0.00415517367883999969    0.00620237987144000007
# amax             0.79298245820900004066    0.85554993405599999434
# before_last      0.71303513476600000054    0.58111496260200001807
# quantile_high    0.50583069728300000811    0.47684946836899999578
# sum            221.51103382852187451135  217.21963889178613271724
# median           0.20061813022700000775    0.19873642680199998800
# quantile_50      0.20061813022700000775    0.19873642680199998800
#
#                         US6092071058 US
# amin             0.00013168698548799999
# second           0.00085935616687600003
# quantile_low     0.00723891980141999972
# amax             0.62190366982900002757
# before_last      0.55771674779000002253
# quantile_high    0.48791753556700001582
# sum            215.09844500844010894980
# median           0.20404436304299999883
# quantile_50      0.20404436304299999883

# %%
s = pd.Series([2,5,1,4,3])
s.sort_values()
sorted(s.array)[-2]
# Out:
# 2    1
# 0    2
# 4    3
# 3    4
# 1    5
# dtype: int64
# 4

# %%
f_name = 'fines.json'
# , orient='values'
# fines = 
with open(f_name) as jf:
    j = json.load(jf)
print('json keys', j.keys())
for key in list(j.keys())[:-1]:
    print(f'    {key}({type(j[key])}): {j[key]}')
print()

jv = json.loads(j['Value'])
print('json Value keys', jv.keys())
print(f'    State', jv['State'])
print()

fines = jv['Fines']

print('Fines[0] key: value:')
for k, v in fines[0].items():
    print(f'    {k}({type(v)}): {v}')
print()
# Out:
# json keys dict_keys(['Message', 'ShowMessage', 'StateCode', 'TimeStamp', 'Value'])
#     Message(<class 'str'>): Операция завершилась удачно!
#     ShowMessage(<class 'bool'>): False
#     StateCode(<class 'str'>): 0
#     TimeStamp(<class 'str'>): 07.03.2018 15:28:44
#
# json Value keys dict_keys(['Fines', 'State'])
#     State 0
#
# Fines[0] key: value:
#     AdminOffensesTypeText(<class 'str'>): Штраф
#     AmountToPay(<class 'int'>): 0
#     ApnDetail(<class 'list'>): [{'AttrId': 'StAP', 'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения', 'Value': '12.17 ч.1.2 - Движение или остановка на полосе для маршрутных ТС в Москве или в Санкт-Петербурге'}, {'AttrId': 'MestoDAP', 'Name': 'Место составления документа', 'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'}, {'AttrId': 'DatNar', 'Name': 'Дата и время нарушения', 'Value': '23.01.2018 00:21:00'}, {'AttrId': 'MestoNar', 'Name': 'Место нарушения', 'Value': 'МОСКВА Г.   МОХОВАЯ д.15/1'}, {'AttrId': 'OdpsName', 'Name': 'Орган власти, выявивший нарушение', 'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'}, {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'}, {'AttrId': 'GRZNarush', 'Name': 'Транспортное средство', 'Value': 'С700*****'}]
#     DAP(<class 'str'>): 18810177180125209293
#     DAPName(<class 'str'>): Постановление по видеофиксации №18810177180125209293 от 25.01.2018
#     DateDAP(<class 'str'>): 25.01.2018
#     DiscountDate(<class 'str'>):
#     DiscountSize(<class 'str'>):
#     DiscountSizeAmountToPaySum(<class 'NoneType'>): None
#     FineStatus(<class 'int'>): 1
#     FineSum(<class 'int'>): 3000
#     HasAdditionalActions(<class 'bool'>): False
#     HasPhoto(<class 'bool'>): True
#     IsFine(<class 'bool'>): True
#     Latitude(<class 'str'>): 55,7563209999
#     Longitude(<class 'str'>): 37,614136
#     OdpsKod(<class 'str'>): 1145519
#     PayedAmountSum(<class 'NoneType'>): None
#     PaymentId(<class 'str'>):
#     Sh(<class 'str'>): {"DAP":"18810177180125209293","DateDAP":"25.01.2018","ODPS":"ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве","PaymentID":null,"RsRschet":"40101810045250010041","SgBuk":"044525000","ShBankName":"ГУ Банка России по ЦФО","ShInn":"7707089101","ShKbk":"18811630020016000140","ShKpp":"770731005","ShOkato":"45379000","ShPoluchName":"УФК по г. Москве (УГИБДД ГУ МВД России по г.Москве)","Sum":3000,"Uin":"18810177180125209293"}
#     Sts(<class 'str'>): 7741525886
#     Type(<class 'int'>): 0
#     UID(<class 'str'>): f9e58750-5f64-4138-942a-67e0967d4547
#     VidNak(<class 'str'>): 2
#     VstupDate(<class 'str'>):
#     Vu(<class 'str'>):

# %%
import numpy as np
df = pd.DataFrame(data=[x.values() for x in fines], columns=fines[0].keys())
with pd.option_context("max_colwidth", 120):
    df1: pd.DataFrame = df[['AdminOffensesTypeText', 'AmountToPay', 'DAPName']]
    # df1
    # df1[[not x for x in np.isnan(df.AmountToPay)]]
    df1.loc[~np.isnan(df.AmountToPay)]
# Out:
#     AdminOffensesTypeText  AmountToPay  \
# 0                   Штраф          0.0
# 258                 Штраф          0.0
# 545                 Штраф          0.0
# 817                 Штраф          0.0
#
#                                                                 DAPName
# 0    Постановление по видеофиксации №18810177180125209293 от 25.01.2018
# 258  Постановление по видеофиксации №18810177180114012094 от 14.01.2018
# 545  Постановление по видеофиксации №18810177180102236898 от 02.01.2018
# 817     Протокол по делу 20.25 №0356043010117070700001076 от 07.07.2017

# %%
with pd.option_context("max_colwidth", 1000):
    df.loc[0][['ApnDetail']]
# Out:
# ApnDetail    [{'AttrId': 'StAP', 'Name': 'Статья КоАП или закона субъекта РФ, состав правонарушения', 'Value': '12.17 ч.1.2 - Движение или остановка на полосе для маршрутных ТС в Москве или в Санкт-Петербурге'}, {'AttrId': 'MestoDAP', 'Name': 'Место составления документа', 'Value': 'САДОВАЯ-САМОТЕЧНАЯ,д.1,ТВЕРСКОЙ (ЦАО) Р-Н'}, {'AttrId': 'DatNar', 'Name': 'Дата и время нарушения', 'Value': '23.01.2018 00:21:00'}, {'AttrId': 'MestoNar', 'Name': 'Место нарушения', 'Value': 'МОСКВА Г.   МОХОВАЯ д.15/1'}, {'AttrId': 'OdpsName', 'Name': 'Орган власти, выявивший нарушение', 'Value': 'ЦАФАП ОДД ГИБДД ГУ МВД России по г.Москве'}, {'AttrId': 'FIONarush', 'Name': 'Нарушитель', 'Value': 'ЛЕОНИД ЭДУАРДОВИЧ'}, {'AttrId': 'GRZNarush', 'Name': 'Транспортное средство', 'Value': 'С700*****'}]
# Name: 0, dtype: object

# %%
def cond1(x):
    print(type(x))
    return False

with pd.option_context("max_colwidth", 100):
    # df.loc[]
    df.ApnDetail[[len(df.ApnDetail[k].array)>2 for k in df.ApnDetail.keys()]]
    # df.ApnDetail.array
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [22], in <module>
#       3     return False
#       5 with pd.option_context("max_colwidth", 100):
#       6     # df.loc[]
# ----> 7     df.ApnDetail[[len(df.ApnDetail[k].array)>2 for k in df.ApnDetail.keys()]]
#
# Input In [22], in <listcomp>(.0)
#       3     return False
#       5 with pd.option_context("max_colwidth", 100):
#       6     # df.loc[]
# ----> 7     df.ApnDetail[[len(df.ApnDetail[k].array)>2 for k in df.ApnDetail.keys()]]
#
# AttributeError: 'list' object has no attribute 'array'

# %%
with pd.option_context("max_colwidth", 120):
    df.loc[0][['ApnDetail']][1]array
# Out:
#   Input In [23]
#     df.loc[0][['ApnDetail']][1]array
#                                ^
# SyntaxError: invalid syntax
